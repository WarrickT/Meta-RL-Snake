# %%
import sys
import os

# Add META-RL-SNAKE (project root) to path
project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from meta_snake_rl.env.snake_env import SnakeEnv, select_action, get_state
from meta_snake_rl.utils.constants import ACTIONS, OPPOSITE

# %%
from meta_snake_rl.train.training_loops import meta_sarsa_loop
from meta_snake_rl.utils.visualizer import plot_rewards_progress
from meta_snake_rl.test.test_policy import test_policy

# %%
Q_test, rewards_test = meta_sarsa_loop(
    variants=["classic", "moving_apple", "obstacles"],
    alpha=0.1,
    gamma=0.95,
    epsilon=1.0,
    min_epsilon=0.05,
    decay_rate=0.995,
    episodes=3000
)

# %%
for v in ["classic", "moving_apple", "obstacles"]:
    test_policy(Q_test, variant=v)
# Out:
# Starting episode #  1  for  classic
# Done episode #  1  with reward  15  for  classic
# Starting episode #  2  for  classic
# Done episode #  2  with reward  23  for  classic
# Starting episode #  3  for  classic
# Done episode #  3  with reward  18  for  classic
# Starting episode #  4  for  classic
# Done episode #  4  with reward  23  for  classic
# Starting episode #  5  for  classic
# Done episode #  5  with reward  22  for  classic
# Starting episode #  6  for  classic
# Done episode #  6  with reward  28  for  classic
# Starting episode #  7  for  classic
# Done episode #  7  with reward  26  for  classic
# Starting episode #  8  for  classic
# Done episode #  8  with reward  15  for  classic
# Starting episode #  9  for  classic
# Done episode #  9  with reward  21  for  classic
# Starting episode #  10  for  classic
# Done episode #  10  with reward  24  for  classic
# Starting episode #  11  for  classic
# Done episode #  11  with reward  19  for  classic
# ...

# %% [markdown]
# The snake gets stuck a LOT in the obstacles variation!

# %% [markdown]
# ## Apply Grid Search to this algorithm
